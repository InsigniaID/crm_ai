# %%
from Test.open import AI_API
import pandas as pd
import sqldf
import itertools
import openai

# %%
pd.set_option('display.max_rows', None)

# %%
df_campaign = pd.read_csv('../JUL2023/2023_JULY_CAMPAIGN.csv')
df_add = pd.read_csv('Test/sample_page_location.csv')

# %%
df = df_campaign.merge(df_add, left_on='campaign_name', right_on='session_campaign_name', how='left')

# %%
grouped_data = df.groupby(['campaign_name', 'page_location']).sum()[['Unique Open', 'Unique Click']]
# Out:
# C:\Users\wvinc\AppData\Local\Temp\ipykernel_18740\1710864321.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df.groupby(['campaign_name', 'page_location']).sum()[['Unique Open', 'Unique Click']]

# %%
grouped_data['CTR'] = grouped_data['Unique Click'] / grouped_data['Unique Open']

# %%
grouped_data
# Out:
#                                                                                                        Unique Open  \
# campaign_name                                      page_location
# 20230707_EDM_MAA KIDS_Bricks DF_Voucher Sign Up... https://bricksactive.id/promo/lego-disney-100?u...           48
#                                                    https://www.bricksactive.id/sign-up-voucher.htm...           48
# 20230713_EDM_MAA KIDS_Bricks DF_LEGO D100          https://bricksactive.id/                                  12592
#                                                    https://bricksactive.id/?utm_source=Email&utm_m...        37776
#                                                    https://bricksactive.id/?utm_source=Email&utm_m...        12592
#                                                    https://bricksactive.id/?utm_source=Email&utm_m...        12592
# ...

# %%
result = df.groupby('campaign_name')['page_location'].nunique().sort_values(ascending=False)

# %%
print(result)
# Out:
# campaign_name
# 20230721_EDM_MAA KIDS_Bricks DF_Ninjago 25%                                         66
# 20230715_EDM_MAA KIDS_Bricks DF_Little Mermaid                                      64
# 20230713_EDM_MAA KIDS_Bricks DF_LEGO D100                                           53
# 20230719_EDM_MAA KIDS_Bricks DF_Batcave                                             52
# 20230728_EDM_MAA KIDS_Bricks DF_Store Activity                                       4
# 20230707_EDM_MAA KIDS_Bricks DF_Voucher Sign Up BricksActive                         2
# 20230714_EDM_MAA KIDS_Bricks DF_QR Voucher announcement                              1
# 20230723_EDM_MAA KIDS_KSA DF_Smiggle BTS                                             0
# 20230725_EDM_MAA KIDS_KSA DF_Payday Ekslusif Deals & LEGO PAYDAY                     0
# 20230725_EDM_MAA KIDS_Bricks DF_Payday D2C & Up House                                0
# 20230725_EDM_MAA FFW_SM DF_Warm up 2                                                 0
# ...

# %%
pd.set_option('display.max_rows', None)
